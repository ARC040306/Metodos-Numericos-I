# %% [markdown]
# <a href="https://colab.research.google.com/github/ARC040306/Metodos-Numericos-I/blob/main/Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# Función cuadrática.
def f(x):
    return x - 3**(-x)

# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)
# Graficar ambas funciones.
plt.plot(x, f(x))
plt.axhline(0, color="black")
plt.axvline(0, color="black")
plt.xlim(-5, 5)
plt.ylim(-5, 5)
title
#plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.grid(color = "black")
plt.show()

# %%
# Función cuadrática.
def f(x):
    return x

# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)
# Graficar ambas funciones.
plt.figure(figsize=(10,10))
plt.plot(x, f(x))
plt.axhline(0, color="pink")
plt.axvline(0, color="pink")
plt.xlim(-5, 5)
plt.ylim(-5, 5)
#plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.grid(color = "orange")
def f(x):
    return -3**(-x)
plt.plot(x,f(x))
def f(x):
    return x - 3**(-x)
plt.plot(x,f(x))
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title("Modelando funciones")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.figtext(1,1, "En está gráfica se puede observar la gráfica h(x) = -3^(-x) y g(x) = x, al igual que la suma de ambas f(x) = x - 3 ^ -x")
plt.show()
