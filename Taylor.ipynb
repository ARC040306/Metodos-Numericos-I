# %% [markdown]
# <a href="https://colab.research.google.com/github/ARC040306/Metodos-Numericos-I/blob/main/Taylor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# Función cuadrática.
def f(x):
    return 1 + (1/2) * x
def h(x):
    return 1 + (1/2) * x - (1/8)* x**2
plt.plot(x,h(x))
def g(x):
    return 1 + (1/2) * x - (1/8)* x**2 + (1/16)
# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)
# Graficar ambas funciones.
plt.plot(x, f(x))
plt.axhline(0, color="black")
plt.axvline(0, color="black")
plt.xlim(-5, 5)
plt.ylim(-5, 5)

#plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.grid(color = "black")
plt.show()
